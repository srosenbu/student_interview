# %% [markdown]
# # Task: Statistical analysis
#
# You are given a dataset containing samples from an unknown statistical model, and an implementation of a model as a black box that can be sampled from. Your task is to determine whether the observations could plausibly have been generated by the model.
#
# You may use any statistical method you like, but you must justify your choice of method and your interpretation of the results. Explain why you chose the method, what assumptions it makes, and how the results support your conclusion.
#
# You may use large language models like ChatGPT or GitHub Copilot to find the appropriate method and to help write code, but you must explain your reasoning and the steps you took to arrive at your conclusion. A simple method that you can confidently explain is better than a complex method that you don't understand.
#
# The conda environment is set up with the following packages:
# ```
#   - python=3.10
#   - numpy
#   - scipy
#   - pandas
#   - matplotlib
#   - seaborn
#   - jupyterlab
# ```
#
# The black box model is implemented in a ibrary `student_interview` which has been compiled for linux. It can be imported like this:

# %%
from student_interview import black_box

# This is a simple script to test the black_box function from the student_interview module.
print(black_box())
# Out:
# 0.792736674456116

# %% [markdown]
# The dataset is given as a list:

# %%
data = [0.02083220643574089,
 0.18273177629006424,
 -0.6390285138099393,
 -0.3760831754654541,
 2.084605266698771,
 -2.758976669391078,
 -2.3048809299422772,
 -1.5689803433560725,
 0.2153694424033101,
 -0.9326245251942831,
 -1.2397679074191024,
 -0.52430633539611,
 -0.7360044670460463,
 1.259771441118135,
 -0.5535834962497534]

import matplotlib.pyplot as plt
plt.hist(data)
plt.title('Histogram of Data')
plt.show()
